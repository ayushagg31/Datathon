# %%
import pandas as pd
import missingno
import matplotlib.pyplot as plt
# %matplotlib inline
import gc

# %%
Path = '/home/gozmit/Desktop/AmExpert2019/train_AUpWtIz/'
train = pd.read_csv(Path + 'train.csv')
campaign_data = pd.read_csv(Path + 'campaign_data.csv')
coupon_item_mapping = pd.read_csv(Path + 'coupon_item_mapping.csv')
customer_demographics = pd.read_csv(Path + 'customer_demographics.csv')
customer_transaction_data = pd.read_csv(Path + 'customer_transaction_data.csv')
item_data = pd.read_csv(Path + 'customer_transaction_data.csv')
test = pd.read_csv('/home/gozmit/Desktop/AmExpert2019/test_QyjYwdj.csv')

# %%
missingno.matrix(train, figsize = (30,10))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78369 entries, 0 to 78368
# Data columns (total 5 columns):
# id                   78369 non-null int64
# campaign_id          78369 non-null int64
# coupon_id            78369 non-null int64
# customer_id          78369 non-null int64
# redemption_status    78369 non-null int64
# dtypes: int64(5)
# memory usage: 3.0 MB

# %%
missingno.matrix(item_data, figsize = (30,10))

# %%
missingno.matrix(customer_demographics, figsize = (30,10))

# %%
customer_demographics.count()

# %%
customer_demographics.isnull().sum()

# %%
customer_demographics.marital_status.value_counts()

# %%
gc.collect()

# %%
customer_data = pd.DataFrame()
customer_data = customer_demographics

# %%
customer_data.drop(['marital_status','no_of_children'],axis=1,inplace=True)

# %%
missingno.matrix(customer_data, figsize = (30,10))

# %%
train.head()

# %%
campaign_data.head()

# %%
customer_data.count()

# %%
help(pd.merge)

# %%
"""
campaign_data
coupon_item_mapping
customer_demographics
customer_transaction_data
item_data
"""

# %%
final = pd.merge(train, customer_data, on='customer_id',how='inner')

# %%
final.to_csv('../final.csv', index=False)

# %%
final.count()

# %%
final = pd.merge(train, customer_data, on='customer_id',how='inner')
